# %% [markdown]
# # Higgs Classification
#
# By Alexander Chkodrov
# November 11th, 2019
#
# Perform an inclusive search for the standard model Higgs boson in pp collisions at √ s = 13 TeV at the LHC using simulated data. Use a set of training datasets to optimize event selections in order to enhance the discovery sensitivity. The optimal event selections will be applied to a selected pseudo-experiment data.

# %%
import pickle
import pandas as pd
import numpy as np
import scipy
import matplotlib.pyplot as plt

#import scikit

# %%
infile_qcd = open("qcd_100000_pt_250_500.pkl", 'rb')
qcd_dict = pickle.load(infile_qcd)

infile_higgs = open("higgs_100000_pt_250_500.pkl", 'rb')
higgs_dict = pickle.load(infile_higgs)

# %% [markdown]
# In this analysis the goal is to confirm the existance of the Higgs boson with maximum confidence. Direct observation of the Higgs is obscured by QCD background contamination, so instead observation of the parameters/features influenced by the presence of the Higgs boson will confirm discovery.
#
# Below, a histogram of all 14 features of the jets for both higgs (orange) and qcd (blue) data sets.

# %%
fig, ax_arr = plt.subplots(len(qcd_dict.keys()),1, figsize=(15,100))
index = 0
qcd_hists = pd.DataFrame()
higgs_hists = pd.DataFrame()
for key in qcd_dict.keys():
    ax_arr[index].hist(qcd_dict.get(key), bins=100, density=True)
    ax_arr[index].title.set_text(key)
    ax_arr[index].hist(higgs_dict.get(key), bins=100, density=True)
    ax_arr[index].title.set_text(key)
    index += 1

# %% [markdown]
# Above is a series of histograms for all features in the background data set (blue) and then for all features in the signal data set (orange). Some features, like 'phi', remain constant in both the background and signal data sets; thus the feature has no power to descriminate between background and signal. Other features, like mass, have distinctly different histograms for the background and signal data sets, and can be used to descriminate between the background and signal.
#
# Finding the correlation of our features,

# %%
corr_table=qcd_dict.corr()
corr_table
# Out:
#                   pt       eta       phi      mass       ee2       ee3  \
# pt          1.000000  0.001646 -0.002151  0.116106 -0.065045 -0.071166
# eta         0.001646  1.000000  0.001982  0.000331 -0.000829  0.000016
# phi        -0.002151  0.001982  1.000000  0.001781 -0.000084 -0.001442
# mass        0.116106  0.000331  0.001781  1.000000  0.944705  0.823995
# ee2        -0.065045 -0.000829 -0.000084  0.944705  1.000000  0.888003
# ee3        -0.071166  0.000016 -0.001442  0.823995  0.888003  1.000000
# d2          0.044540  0.003129  0.000616 -0.609440 -0.660044 -0.413854
# angularity -0.006096  0.001901  0.002013  0.395267  0.335057  0.346522
# t1         -0.015842  0.001541  0.000068  0.047805  0.161316  0.163273
# t2         -0.015435  0.003722  0.003766 -0.518935 -0.519772 -0.304939
# t3         -0.012933  0.001989  0.004418 -0.597166 -0.613476 -0.408181
# t21        -0.010350  0.002678  0.003519 -0.571218 -0.621209 -0.388633
# t32         0.002034 -0.002362  0.002664 -0.369384 -0.412979 -0.400095
# KtDeltaR   -0.020723  0.002631 -0.003412  0.709354  0.661513  0.533815
#
#                   d2  angularity        t1        t2        t3       t21  \
# pt          0.044540   -0.006096 -0.015842 -0.015435 -0.012933 -0.010350
# eta         0.003129    0.001901  0.001541  0.003722  0.001989  0.002678
# phi         0.000616    0.002013  0.000068  0.003766  0.004418  0.003519
# mass       -0.609440    0.395267  0.047805 -0.518935 -0.597166 -0.571218
# ee2        -0.660044    0.335057  0.161316 -0.519772 -0.613476 -0.621209
# ee3        -0.413854    0.346522  0.163273 -0.304939 -0.408181 -0.388633
# d2          1.000000   -0.174517 -0.110423  0.505221  0.553272  0.600450
# angularity -0.174517    1.000000  0.013484 -0.069498 -0.099513 -0.090325
# t1         -0.110423    0.013484  1.000000  0.285307  0.206263 -0.087536
# t2          0.505221   -0.069498  0.285307  1.000000  0.934555  0.913813
# t3          0.553272   -0.099513  0.206263  0.934555  1.000000  0.880102
# t21         0.600450   -0.090325 -0.087536  0.913813  0.880102  1.000000
# t32         0.239771   -0.109640 -0.151472  0.057613  0.390869  0.119692
# KtDeltaR   -0.466225    0.263082 -0.209706 -0.675798 -0.683419 -0.621312
#
#                  t32  KtDeltaR
# pt          0.002034 -0.020723
# eta        -0.002362  0.002631
# phi         0.002664 -0.003412
# mass       -0.369384  0.709354
# ee2        -0.412979  0.661513
# ee3        -0.400095  0.533815
# d2          0.239771 -0.466225
# angularity -0.109640  0.263082
# t1         -0.151472 -0.209706
# t2          0.057613 -0.675798
# t3          0.390869 -0.683419
# t21         0.119692 -0.621312
# t32         1.000000 -0.189381
# KtDeltaR   -0.189381  1.000000

# %%
a = (corr_table-np.eye(len(corr_table))).max()
b = (corr_table-np.eye(len(corr_table))).idxmax()
pd.DataFrame([a,b]).T
# Out:
#                      0     1
# pt            0.116106  mass
# eta          0.0037221    t2
# phi         0.00441806    t3
# mass          0.944705   ee2
# ee2           0.944705  mass
# ee3           0.888003   ee2
# d2             0.60045   t21
# angularity    0.395267  mass
# t1            0.285307    t2
# t2            0.934555    t3
# t3            0.934555    t2
# t21           0.913813    t2
# t32           0.390869    t3
# KtDeltaR      0.709354  mass

# %% [markdown]
# Above is a list of the maximum correlation coefficients between feautures; mass, ee2, and ee3 are highly correlated with eachother, and the tN values are highly correlated with the exception of t32.
#
# Now, find the best features to descriminate between signal and background.

# %%
pt = qcd_dict.get('pt') - higgs_dict.get('pt')

# %%
qcd_dict.get('angularity').hist(bins=20, density=True)
higgs_dict.get('angularity').hist(bins=20, density=True)

# %%
dat2 = plt.hist(higgs_dict.get('mass'), bins=100, density=True)
dat1 = plt.hist(qcd_dict.get('mass'), bins=100, density=True)

# %% [markdown]
# Normalize and use histogram as pdf for features from background data.

# %%
qcd_normdat = 1/sum(dat1[0])*dat1[0]
qcd_x = np.linspace(dat1[1][0], dat1[1][-1], len(qcd_normdat))
qcd_normalized_mass_pdf = pd.DataFrame(qcd_normdat, index=qcd_x)

higgs_normdat = 1/sum(dat2[0])*dat2[0]
higgs_x = np.linspace(dat2[1][0], dat2[1][-1], len(higgs_normdat))
higgs_normalized_mass_pdf = pd.DataFrame(higgs_normdat, index=qcd_x)

# %%
plt.plot(qcd_x, qcd_normdat)
plt.show()
plt.plot(higgs_x, higgs_normdat)
plt.show()

# %%
sum(qcd_normdat)
# Out:
# 1.000000000000001

# %%
print(len(higgs_dict.get('mass')[higgs_dict.get('mass')>132]))
print(len(qcd_dict.get('mass')[qcd_dict.get('mass')>132]))
# Out:
# 555
# 18438

# %% [markdown]
# What approach do I take here? Do I use machine learning classification, or model each feature as some sort of distribution by hand?
#
# How does the expected yield Nhiggs=500 influence my data/what I do?
#
# How do I compute discovery significance? do I do it over multiple trials?
# Because our practiced method of using the CDF() would not be very effective. Use bayesian probability maybe?
#
# Consider the histogram of qcd as average pdf of a single observation, then convolve it and do something with that?
#
# What does expected yield qcd=20,000 mean with 100,000 observations? What are the other 80,000 observations of?
#
# Where am I supposed to actually learn about the higgs boson and any of this???

# %%
qcd_normalized_mass_pdf
# Out:
#                   0
# 9.292817    0.00003
# 12.445395   0.00012
# 15.597972   0.00032
# 18.750550   0.00070
# 21.903127   0.00158
# ...             ...
# 308.787683  0.00001
# 311.940261  0.00004
# 315.092838  0.00004
# 318.245416  0.00000
# 321.397993  0.00007
#
# [100 rows x 1 columns]

# %%
len(qcd_dict.get('mass'))
# Out:
# 100000
